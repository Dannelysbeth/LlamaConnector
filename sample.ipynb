# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import requests

response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": "llama3.2",
        "prompt": "Explain CAP in SAP in simple terms",
        "stream": False
    }
)

print(response.json()["response"])
# Out:
# In simple terms, CAP (Consistency, Availability, and Partition tolerance) is a concept that helps organizations design distributed systems that can handle high availability, scalability, and reliability.
#
# Here's how it applies to SAP:
#
# **What does each component mean?**
#
# 1. **Consistency**: This refers to the accuracy and precision of data across all nodes (computers or servers) in your system. In other words, everything should be up-to-date and accurate.
# 2. **Availability**: This means that users can access the system at any time without interruption. No matter what happens, the system should always be available.
# 3. **Partition tolerance**: This refers to how the system handles failures or partitions (divisions) in the network. If a partition occurs, the system should still function and provide results.
#
# **SAP's CAP approach**
#
# In SAP, you can design your system using three possible approaches:
#
# 1. **Strong consistency**: All nodes always agree on data values. This is useful when data accuracy is crucial, but it might impact availability.
# 2. **Weak consistency**: Nodes may have different data values temporarily until they sync up with each other. This approach balances consistency and availability.
# 3. **Eventually consistent**: Data may be out of date for a while before being synchronized across all nodes. This approach prioritizes availability over consistency.
#
# **SAP's choice**
#
# SAP typically chooses to use the weak consistency approach, which means that data may not always be up-to-date across all nodes. However, this ensures high availability and scalability for large-scale systems.
#
# In summary, CAP in SAP is about designing distributed systems that balance consistency, availability, and partition tolerance to ensure high performance, reliability, and scalability.
